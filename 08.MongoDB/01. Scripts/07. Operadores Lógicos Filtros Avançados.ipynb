# %%
from pymongo import MongoClient
import pandas   as pd 
pd.set_option('display.max_columns', None)  

client = MongoClient('mongodb+srv://user-silvio:1989@cluster-aula.glssz5i.mongodb.net/')
db = client['Aula']
colletion= db.get_collection('anac')

filter={'$and':[{'UF':'MG'},{'Classificacao_da_Ocorrência':'Acidente'}]}
columns ={'Numero_da_Ocorrencia':1,'Classificacao_da_Ocorrência':1,'UF':1,'PSSO':1}

data = list(colletion.find(filter,columns))
df = pd.DataFrame(data)
df.head(5)
# Out:
#                         _id Numero_da_Ocorrencia Classificacao_da_Ocorrência  \
# 0  68361c9965b7b847299d068b                 7759                    Acidente
# 1  68361c9965b7b847299d06a2                 7516                    Acidente
# 2  68361c9965b7b847299d06ab                 7511                    Acidente
# 3  68361c9965b7b847299d0713                 7208                    Acidente
# 4  68361c9965b7b847299d0773                 7703                    Acidente
#
#    UF        PSSO
# 0  MG  verdadeiro
# 1  MG       falso
# 2  MG  verdadeiro
# 3  MG  verdadeiro
# 4  MG  verdadeiro

# %%
from pymongo import MongoClient
import pandas   as pd 
pd.set_option('display.max_columns', None)  

client = MongoClient('mongodb+srv://user-silvio:1989@cluster-aula.glssz5i.mongodb.net/')
db = client['Aula']
colletion= db.get_collection('anac')

filter={'$or':[{'UF':'GO'},{'PSSO':'verdadeiro'}]}
columns ={'Numero_da_Ocorrencia':1,'Classificacao_da_Ocorrência':1,'UF':1,'PSSO':1}

data = list(colletion.find(filter,columns))
df = pd.DataFrame(data)
df.head(35)
# Out:
#                          _id Numero_da_Ocorrencia Classificacao_da_Ocorrência  \
# 0   68361c9965b7b847299d068a                 7762                   Incidente
# 1   68361c9965b7b847299d068b                 7759                    Acidente
# 2   68361c9965b7b847299d068c                 7758                    Acidente
# 3   68361c9965b7b847299d068d                 7758                    Acidente
# 4   68361c9965b7b847299d068e                 7757             Incidente Grave
# 5   68361c9965b7b847299d0690                 5118                    Acidente
# 6   68361c9965b7b847299d0693                 7754             Incidente Grave
# 7   68361c9965b7b847299d0694                 7754             Incidente Grave
# 8   68361c9965b7b847299d0695                 7753                    Acidente
# 9   68361c9965b7b847299d0697                 5665                    Acidente
# 10  68361c9965b7b847299d0699                 7526                   Incidente
# 11  68361c9965b7b847299d069b                 7524          Ocorrência de Solo
# 12  68361c9965b7b847299d069c                 7523                   Incidente
# 13  68361c9965b7b847299d069d                 7522                    Acidente
# 14  68361c9965b7b847299d069f                 7520                   Incidente
# 15  68361c9965b7b847299d06a0                 7519                   Incidente
# 16  68361c9965b7b847299d06a1                 7518                   Incidente
# 17  68361c9965b7b847299d06a3                 7514                   Incidente
# 18  68361c9965b7b847299d06a4                 7517                   Incidente
# 19  68361c9965b7b847299d06a5                 7515             Incidente Grave
# 20  68361c9965b7b847299d06a6                 7229                   Incidente
# 21  68361c9965b7b847299d06a7                 7228                   Incidente
# 22  68361c9965b7b847299d06a8                 7227          Ocorrência de Solo
# 23  68361c9965b7b847299d06a9                 7513                   Incidente
# 24  68361c9965b7b847299d06ab                 7511                    Acidente
# 25  68361c9965b7b847299d06ac                 7510                   Incidente
# 26  68361c9965b7b847299d06ad                 7236                   Incidente
# 27  68361c9965b7b847299d06af                 7234                   Incidente
# 28  68361c9965b7b847299d06b0                 7233                    Acidente
# 29  68361c9965b7b847299d06b1                 7232                    Acidente
# 30  68361c9965b7b847299d06b2                 7231                   Incidente
# 31  68361c9965b7b847299d06b3                 7230                   Incidente
# 32  68361c9965b7b847299d06b4                 7226                   Incidente
# 33  68361c9965b7b847299d06b5                 7225                    Acidente
# 34  68361c9965b7b847299d06b6                 7224                    Acidente
#
#                UF        PSSO
# 0              SP  verdadeiro
# 1              MG  verdadeiro
# 2              GO  verdadeiro
# 3              GO  verdadeiro
# 4              RS  verdadeiro
# 5              ES  verdadeiro
# 6              SP  verdadeiro
# 7              SP  verdadeiro
# 8              SP  verdadeiro
# 9   Indeterminado  verdadeiro
# 10             MG  verdadeiro
# 11             RJ  verdadeiro
# 12             SP  verdadeiro
# 13             RR  verdadeiro
# 14             SP  verdadeiro
# 15             PR  verdadeiro
# 16             PR  verdadeiro
# 17             SC  verdadeiro
# 18             PE  verdadeiro
# 19             MT  verdadeiro
# 20             RJ  verdadeiro
# 21             SP  verdadeiro
# 22             RJ  verdadeiro
# 23             PR  verdadeiro
# 24             MG  verdadeiro
# 25             MG  verdadeiro
# 26             MG  verdadeiro
# 27             BA  verdadeiro
# 28             MS  verdadeiro
# 29             AM  verdadeiro
# 30             SC  verdadeiro
# 31             ES  verdadeiro
# 32             MG  verdadeiro
# 33             GO       falso
# 34             SP  verdadeiro
