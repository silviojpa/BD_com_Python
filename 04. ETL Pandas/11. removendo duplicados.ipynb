# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html

# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\silvio\Documents\Curso BD\Udemy\Arquivos\04.+ETL+Pandas\04. ETL Pandas\arquivos_excel\Produto.xlsx")
df.head(10)
# Out:
#    ID                  Name  Price  Id_Category
# 0   0       Sapato vermelho     96            0
# 1   1  Bolsa mais que Velha   8000            0
# 2   2                 Calça     75            0
# 3   3    Camisa apertadinha    170            0
# 4   4   Vestido Super curto     57            0
# 5   5               Perfume     29            1
# 6   6      Creme de Barbear     15            1
# 7   7       Hidratante caro    800            1
# 8   8               Shampoo     15            1
# 9   9        Protetor Solar     11            1

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
df.duplicated(['Name'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
Duplicados = df[df.duplicated()]

# %%
Duplicados
# Out:
# Empty DataFrame
# Columns: [ID, Name, Price, Id_Category]
# Index: []

# %%
# Remova as duplicatas do DataFrame
df_sem_duplicatas = df.drop_duplicates()

# %%
df_sem_duplicatas
# Out:
#     ID                  Name  Price  Id_Category
# 0    0       Sapato vermelho     96            0
# 1    1  Bolsa mais que Velha   8000            0
# 2    2                 Calça     75            0
# 3    3    Camisa apertadinha    170            0
# 4    4   Vestido Super curto     57            0
# 5    5               Perfume     29            1
# 6    6      Creme de Barbear     15            1
# 7    7       Hidratante caro    800            1
# 8    8               Shampoo     15            1
# 9    9        Protetor Solar     11            1
# 10  10             Geladeira   1952            2
# 11  11                 Fogão   1373            2
# 12  12                    TV   1992            2
# 13  13      Máquina de Lavar   1826            2
# 14  14      Máquina de Secar   1774            2
# 15  15   O Romance Exagerado     46            3
# 16  16       Suspense Demais     42            3
# 17  17  Terror Aterrorizante     45            3
# ...

# %%
df = pd.read_excel(r"C:\Users\silvio\Documents\Curso BD\Udemy\Arquivos\04.+ETL+Pandas\04. ETL Pandas\arquivos_excel\Produto.xlsx")
df.head(10)

# %%
# Remova as duplicatas da coluna "ID"
df_sem_duplicatas2 = df.drop_duplicates(subset=['ID'])

# %%
df_sem_duplicatas2

# %%
df = pd.read_excel(r"C:\Users\silvio\Documents\Curso BD\Udemy\Arquivos\04.+ETL+Pandas\04. ETL Pandas\arquivos_excel\Produto.xlsx")
df.head(10)

# %%
# Remova diretamente  as duplicatas do DataFrame inplace
df.drop_duplicates(inplace=True)

# %%
df
